# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiNg13249/KoreanStudy/blob/main/Korean_grammar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
LINECHAR = '='

grammars = {
    "Talking about future plans": "V(으)ㄹ 거예요",

}

baseforms = {
    "가다": "x","사다": "x", "엽습하다": "x","마시다": "x","자다":"x","예약하다": "x","되다":"x",
    "읽다": "o","먹다": "o","있다":"o",
    "줍다": "ㅂ",
    "걷다": "ㄷ", "듣다": "ㄷ",
    "살다": "ㄹ", "놀다": "ㄹ","만들다":"ㄹ",
    "입다": "*",
    "씹다": "*",
    "받다": "*",
    "닫다": "*",
    #형용사
    "유명하다": "xx", "복잡하다": "xx", "따뜻하다": "xx", "비싸다": "xx",
    "좋다": "oo", "있다":"oo", "싶다": "oo",
    "춥다": "ㅂㅂ", "맵다": "ㅂㅂ", "어렵다": "ㅂㅂ",
    "멀다": "ㄹㄹ"
}

pastforms = {
    "가다": "갔다","사다": "샀다", "엽습하다": "연습했다","마시다": "마셨다","자다":"잤다","예약하다": "예약했다","되다":"됬다",
    "읽다": "읽었다","먹다": "먹었다","있다":"있었다",
    "줍다": "주웠다",
    "걷다": "걸었다", "듣다": "들었다",
    "살다": "살았다", "놀다": "놀았다","만들다":"만들었다",
    "입다": "입었다",
    "씹다": "씹었다",
    "받다": "받았다",
    "닫다": "닫았다",
    #형용사
    "유명하다": "유명했다", "복잡하다": "복잡했다", "따뜻하다": "따뜻했다", "비싸다": "비쌌다",
    "좋다": "좋았다", "있다":"있었다", "싶다": "싶었다",
    "춥다": "추웠다", "맵다": "매웠다", "어렵다": "어려웠다",
    "멀다": "멀었다"
}

meet으 = {
    "가다": "가","사다": "사", "엽습하다": "엽습하","마시다": "마시","자다":"자","예약하다": "예약하",
    "읽다": "읽으","먹다": "먹으",
    "줍다": "주우",
    "걷다": "걸으", "듣다": "들으",
    "살다": "살", "놀다": "놀",
    "입다": "입으",
    "씹다": "씹으",
    "받다": "받으",
    "닫다": "닫으",
    #형용사
    "유명하다": "유명하", "복잡하다": "복잡하", "따뜻하다": "따뜻하", "비싸다":"비싸",
    "좋다": "좋으", "있다":"있으", "싶다": "싶으",
    "춥다": "추우", "맵다": "매우",
    "멀다": "idk"
}

meet으시 = {
    "가다": "가시","사다": "사시", "엽습하다": "엽습하시","마시다": "드시","자다":"주무시","예약하다": "예약하시",
    "읽다": "읽으시","먹다": "드시",
    "줍다": "주우시",
    "걷다": "걸으시", "듣다": "들으시",
    "살다": "사시", "놀다": "노시",
    "입다": "입으시",
    "씹다": "씹으시",
    "받다": "받으시",
    "닫다": "닫으시",
    #형용사
    "유명하다": "유명하시", "복잡하다": "복잡하시", "따뜻하다": "따뜻하시", "비싸다":"비싸시",
    "좋다": "좋으시","있다":"있으시", "싶다":"싶으시",
    "춥다": "추우시", "맵다": "매우시",
    "멀다": "idk"
}

meet으ㄹ = {
    "가다": "갈","사다": "살", "엽습하다": "엽습할","마시다": "마실","자다":"잘","예약하다": "예약할",
    "읽다": "읽을","먹다": "먹을",
    "줍다": "주울",
    "걷다": "걸을", "듣다": "들을",
    "살다": "살", "놀다": "놀",
    "입다": "입을",
    "씹다": "씹을",
    "받다": "받을",
    "닫다": "닫을",
}

meet으실 = {
    "가다": "가실","사다": "사실", "엽습하다": "엽습하실","마시다": "드실","자다":"주무실","예약하다": "예약하실",
    "읽다": "읽으실","먹다": "드실",
    "줍다": "주우실",
    "걷다": "걸으실", "듣다": "들으실",
    "살다": "사실", "놀다": "노실",
    "입다": "입으실",
    "씹다": "씹으실",
    "받다": "받으실",
    "닫다": "닫으실",
}

def printl(input, length):
    for i in range(length):
        print(input, end="")
    print()

def getChar(hangul):
    print("Code of ", hangul, "is ", ord(hangul))

def searchCode():
    hangulinput = input("Enter the hangul you want to convert to number: ")
    while hangulinput != ".":
        getChar(hangulinput)
        hangulinput = input("Enter the hangul you want to convert to number: ")

def printSimilar(base):
    print("Similar bases:", end="")
    for x in baseforms:
        if baseforms[x] == baseforms[base] and base != x:
            print(x,end=" ")
    print()

def 거예요(verb):
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -ㄹ 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "o":
            print("(받침 o: -을 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "ㅂ":
            print("(ㅂ 불규칙: -울 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ을 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "ㄹ":
            print("(ㄹ 불규칙: -거예요 ㄹ+으=drop으)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "*":
            print("(Always Regular)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case default:
            print("A verb is needed for 거예요.")
    print("존댓말: ")
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "o":
            print("(받침 o: -으실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "ㅂ":
            print("(ㅂ 불규칙: -우실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ으실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "ㄹ":
            print("(ㄹ 불규칙: -실 거예요 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "*":
            print("(Always Regular)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case default:
            print("A verb is needed for 거예요.")
    printl(LINECHAR,5)

def 으면(adjverb):
    match(baseforms[adjverb]):
        case "x"|"xx":
            print("(받침 x: -면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "o"|"oo":
            print("(받침 o: -으면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "ㅂ"|"ㅂㅂ":
            print("(ㅂ 불규칙: -우면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "ㄷ"|"ㄷㄷ":
            print("(ㄷ 불규칙: -ㄹ으면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "ㄹ"|"ㄹㄹ":
            print("(ㄹ 불규칙: -면 ㄹ+으=drop으)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "*"|"**":
            print("(Always Regular)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case default:
            print("A verb or an adj. is needed for 으면.")
    print("존댓말: ")
    match(baseforms[adjverb]):
        case "x"|"xx":
            print("(받침 x: -시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "o"|"oo":
            print("(받침 o: -으시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "ㅂ"|"ㅂㅂ":
            print("(ㅂ 불규칙: -우시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "ㄷ"|"ㄷㄷ":
            print("(ㄷ 불규칙: -ㄹ으시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "ㄹ"|"ㄹㄹ":
            print("(ㄹ 불규칙: -시면 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "*"|"**":
            print("(Always Regular)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case default:
            print("A verb or an adj. is needed for 으면.")
    printl(LINECHAR,5)

def 수_있다(verb):
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -ㄹ 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "o":
            print("(받침 o: -을 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "ㅂ":
            print("(ㅂ 불규칙: -울 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ을 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "ㄹ":
            print("(ㄹ 불규칙: -수 있다 ㄹ+으=drop으)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "*":
            print("(Always Regular)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case default:
            print("A verb is needed for 수 있다.")
    print("존댓말: ")
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "o":
            print("(받침 o: -으실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "ㅂ":
            print("(ㅂ 불규칙: -우실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ으실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "ㄹ":
            print("(ㄹ 불규칙: -실 수 있다 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "*":
            print("(Always Regular)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case default:
            print("A verb is needed for 수 있다.")
    printl(LINECHAR,5)

def 문어체(adjverbnoun):
    print("A/V-(으)면 of", adjverbnoun, ":", meet으[adjverbnoun]+"면")
    match(baseforms[adjverbnoun]):
        case "x"|"xx"|"xxx":
            print("(받침 x: -면)")
        case "o"|"oo"|"xxx":
            print("(받침 o: -으면)")
        case "ㅂ"|"ㅂㅂ":
            print("(ㅂ 불규칙: -우면)")
        case "ㄷ"|"ㄷㄷ":
            print("(ㄷ 불규칙: -ㄹ으면)")
        case "ㄹ"|"ㄹㄹ":
            print("(ㄹ 불규칙: -면 ㄹ+으=drop으)")
        case "*"|"**":
            print("(Always Regular)")
        case default:
            print("A verb or an adj. is needed.")
    print("A/V-(으)시면 of", adjverbnoun, ":", meet으시[adjverbnoun]+"면")
    match(baseforms[adjverbnoun]):
        case "x"|"xx":
            print("(받침 x: -시면)")
        case "o"|"oo":
            print("(받침 o: -으시면)")
        case "ㅂ"|"ㅂㅂ":
            print("(ㅂ 불규칙: -우시면)")
        case "ㄷ"|"ㄷㄷ":
            print("(ㄷ 불규칙: -ㄹ으시면)")
        case "ㄹ"|"ㄹㄹ":
            print("(ㄹ 불규칙: -시면 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
        case "*"|"**":
            print("(Always Regular)")
        case default:
            print("A verb or an adj. is needed.")
    printl(LINECHAR,5)

def sumVerb(word):
    printl("^",30)
    print("——————————————————")
    print("| Tenses of",word,"|")
    print("——————————————————")

    printSimilar(word)
    printl('=',5)

    거예요(word)
    으면(word)
    수_있다(word)

    printl("v",30)
    print("\n")

#run
sumVerb("가다")
sumVerb("자다")
sumVerb("먹다")
sumVerb("줍다")
sumVerb("듣다")
sumVerb("살다")
sumVerb("받다")
sumVerb("입다")
sumVerb("유명하다")
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 가다 |
# ——————————————————
# Similar bases:사다 엽습하다 마시다 자다 예약하다 되다
# =====
# (받침 x: -ㄹ 거예요)
# V-(으)ㄹ 거예요 of 가다 : 갈 거예요.
# 존댓말:
# (받침 x: -실 거예요)
# V-(으)실 거예요 of 가다 : 가실 거예요.
# =====
# (받침 x: -면)
# A/V-(으)면 of 가다 : 가면
# 존댓말:
# (받침 x: -시면)
# A/V-(으)시면 of 가다 : 가시면
# =====
# (받침 x: -ㄹ 수 있다)
# V-(으)ㄹ 수 있다 of 가다 : 갈 수 있다.
# 존댓말:
# (받침 x: -실 수 있다)
# V-(으)실 수 있다 of 가다 : 가실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 줍다 |
# ——————————————————
# Similar bases:
# =====
# (ㅂ 불규칙: -울 거예요)
# V-(으)ㄹ 거예요 of 줍다 : 주울 거예요.
# 존댓말:
# (ㅂ 불규칙: -우실 거예요)
# V-(으)실 거예요 of 줍다 : 주우실 거예요.
# =====
# (ㅂ 불규칙: -우면)
# A/V-(으)면 of 줍다 : 주우면
# 존댓말:
# (ㅂ 불규칙: -우시면)
# A/V-(으)시면 of 줍다 : 주우시면
# =====
# (ㅂ 불규칙: -울 수 있다)
# V-(으)ㄹ 수 있다 of 줍다 : 주울 수 있다.
# 존댓말:
# (ㅂ 불규칙: -우실 수 있다)
# V-(으)실 수 있다 of 줍다 : 주우실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 듣다 |
# ——————————————————
# Similar bases:걷다
# =====
# (ㄷ 불규칙: -ㄹ을 거예요)
# V-(으)ㄹ 거예요 of 듣다 : 들을 거예요.
# 존댓말:
# (ㄷ 불규칙: -ㄹ으실 거예요)
# V-(으)실 거예요 of 듣다 : 들으실 거예요.
# =====
# (ㄷ 불규칙: -ㄹ으면)
# A/V-(으)면 of 듣다 : 들으면
# 존댓말:
# (ㄷ 불규칙: -ㄹ으시면)
# A/V-(으)시면 of 듣다 : 들으시면
# =====
# (ㄷ 불규칙: -ㄹ을 수 있다)
# V-(으)ㄹ 수 있다 of 듣다 : 들을 수 있다.
# 존댓말:
# (ㄷ 불규칙: -ㄹ으실 수 있다)
# V-(으)실 수 있다 of 듣다 : 들으실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 살다 |
# ——————————————————
# Similar bases:놀다 만들다
# =====
# (ㄹ 불규칙: -거예요 ㄹ+으=drop으)
# V-(으)ㄹ 거예요 of 살다 : 살 거예요.
# 존댓말:
# (ㄹ 불규칙: -실 거예요 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)
# V-(으)실 거예요 of 살다 : 사실 거예요.
# =====
# (ㄹ 불규칙: -면 ㄹ+으=drop으)
# A/V-(으)면 of 살다 : 살면
# 존댓말:
# (ㄹ 불규칙: -시면 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)
# A/V-(으)시면 of 살다 : 사시면
# =====
# (ㄹ 불규칙: -수 있다 ㄹ+으=drop으)
# V-(으)ㄹ 수 있다 of 살다 : 살 수 있다.
# 존댓말:
# (ㄹ 불규칙: -실 수 있다 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)
# V-(으)실 수 있다 of 살다 : 사실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 자다 |
# ——————————————————
# Similar bases:가다 사다 엽습하다 마시다 예약하다 되다
# =====
# (받침 x: -ㄹ 거예요)
# V-(으)ㄹ 거예요 of 자다 : 잘 거예요.
# 존댓말:
# (받침 x: -실 거예요)
# V-(으)실 거예요 of 자다 : 주무실 거예요.
# =====
# (받침 x: -면)
# A/V-(으)면 of 자다 : 자면
# 존댓말:
# (받침 x: -시면)
# A/V-(으)시면 of 자다 : 주무시면
# =====
# (받침 x: -ㄹ 수 있다)
# V-(으)ㄹ 수 있다 of 자다 : 잘 수 있다.
# 존댓말:
# (받침 x: -실 수 있다)
# V-(으)실 수 있다 of 자다 : 주무실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 먹다 |
# ——————————————————
# Similar bases:읽다
# =====
# (받침 o: -을 거예요)
# V-(으)ㄹ 거예요 of 먹다 : 먹을 거예요.
# 존댓말:
# (받침 o: -으실 거예요)
# V-(으)실 거예요 of 먹다 : 드실 거예요.
# =====
# (받침 o: -으면)
# A/V-(으)면 of 먹다 : 먹으면
# 존댓말:
# (받침 o: -으시면)
# A/V-(으)시면 of 먹다 : 드시면
# =====
# (받침 o: -을 수 있다)
# V-(으)ㄹ 수 있다 of 먹다 : 먹을 수 있다.
# 존댓말:
# (받침 o: -으실 수 있다)
# V-(으)실 수 있다 of 먹다 : 드실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 받다 |
# ——————————————————
# Similar bases:입다 씹다 닫다
# =====
# (Always Regular)
# V-(으)ㄹ 거예요 of 받다 : 받을 거예요.
# 존댓말:
# (Always Regular)
# V-(으)실 거예요 of 받다 : 받으실 거예요.
# =====
# (Always Regular)
# A/V-(으)면 of 받다 : 받으면
# 존댓말:
# (Always Regular)
# A/V-(으)시면 of 받다 : 받으시면
# =====
# (Always Regular)
# V-(으)ㄹ 수 있다 of 받다 : 받을 수 있다.
# 존댓말:
# (Always Regular)
# V-(으)실 수 있다 of 받다 : 받으실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 입다 |
# ——————————————————
# Similar bases:씹다 받다 닫다
# =====
# (Always Regular)
# V-(으)ㄹ 거예요 of 입다 : 입을 거예요.
# 존댓말:
# (Always Regular)
# V-(으)실 거예요 of 입다 : 입으실 거예요.
# =====
# (Always Regular)
# A/V-(으)면 of 입다 : 입으면
# 존댓말:
# (Always Regular)
# A/V-(으)시면 of 입다 : 입으시면
# =====
# (Always Regular)
# V-(으)ㄹ 수 있다 of 입다 : 입을 수 있다.
# 존댓말:
# (Always Regular)
# V-(으)실 수 있다 of 입다 : 입으실 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
#
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ——————————————————
# | Tenses of 유명하다 |
# ——————————————————
# Similar bases:복잡하다 따뜻하다 비싸다
# =====
# A verb is needed for 거예요.
# 존댓말:
# A verb is needed for 거예요.
# =====
# (받침 x: -면)
# A/V-(으)면 of 유명하다 : 유명하면
# 존댓말:
# (받침 x: -시면)
# A/V-(으)시면 of 유명하다 : 유명하시면
# =====
# A verb is needed for 수 있다.
# 존댓말:
# A verb is needed for 수 있다.
# =====
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
