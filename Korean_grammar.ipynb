# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiNg13249/KoreanStudy/blob/main/Korean_grammar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

LINECHAR = '='

class Grammar:
    def __init__(self, info, forVerb, forAdj, forNoun,):
        self.info = info
        
    def search(self, word, forVerb, forAdj, forNoun):
        partOfSpeech = baseforms[word].length
        if partOfSpeech == 1 and not(forVerb):
            print("Not for verb")
        elif partOfSpeech == 2 and not(forAdj):
            print("Not for adj")
        elif partOfSpeech == 3 and not(forNoun):
            print("Not for noun")
        else:
            print("For all")

grammars = {
    "Talking about future plans": "V-ㄹ/을 거예요",
    "Talking about future plans (honorific)": "V실/으실 거예요",
    "If/When": "V면/으면; A면/으면",
    "If/When (honorific)": "V시면/으시면; A시면/으시면",
    "Can/Be able to": "V-ㄹ/을 수 있다",
    "Can/Be able to (honorific)": "V실/으실 수 있다",
    "Formal form": "V-ㄴ다/는다; A다; N다/이다",
    "Formal form (honorific)": "V-신다; N시다/이시다",
    "Formal form in past tense": "V-았/-었다; A-았/-었다; N였다/이었다",
    "Formal form in past tense (honorific)": "N셨다/이셨다",
    "Formal form in future tense for V겠어요": "V-겠다",
    "Formal form in future tense for V-ㄹ/을 거예요": "V-ㄹ/을 것이다",
    "Formal form for negating": "V지 않는다; A지 않다; N이/가 아니다",
    "Sentence1 and then Sentence2": "V-아서/-어서; A-아서/-어서; *V(clothes/take transport)고",
    "Sentence1 connect Sentence2": "V고; A고",
    "Negating Sentence": "V지 않다; A지 않다; N이/가 아니다",
    "Formal form for 하고": "N와/과",
    "Indirect speech": "V-ㄴ다고/는다고 하다; A다고 하다; N라고/이라고 하다",
    "Indirect speech (honorific)": "V-신다고 하시다; N시라고/이시라고 하시다",
    "Indirect speech in past tense": "V-았다고/-었다고 하다; A-았다고/-었다고 하다; N였다고/이엇다고 하다",
    "Indirect speech in past tense (honorific)": "V-셨다고/으셨다고 하셨다; N셨/이셨다고 하셨다",
    "Indirect speech in future tense for 겠어요": "V-겠다고 하다; A-겠다고 하다",
    "Indirect speech in future tense for ㄹ/을 거예요": "V-ㄹ/을 거라고 하다; A-ㄹ/을 거라고 하다",
    "Guess": "V는 것 같다; A-ㄴ/은 것 같다; *A(있다/없다)는 것 같다",
    "Guess (honorific)": "V시는 것 같다; A신 것 같다; *A(계시다/계시지 않다)는 것 같다",
    "Guess in past tense": "V-ㄴ/은 것 같다",
    "Guess in past tense (honorific)": "V신/으신 것 같다",
    "Guess in future tense": "V-ㄹ/을 것 같다; A-ㄹ/을 것 같다",
    "Guess in future tense (honorific)": "V실/으실 것 같다; A실/으실 것 같다",
    "Indirect speech when proposing": "V자고 하다",
    "Indirect speech when proposing (honorific)": "V자고 하시다",
    "Indirect speech when disproposing": "V지 말자고 하다",
    "Indirect speech when disproposing (honorific)": "V지 말자고 하시다",
    "Formal form when suggesting": "V지 그래요?",
    "Formal form when suggesting (honorific)": "V시지 그래요?",
    "Formal form when not suggesting": "V지 말지 그래요?",
    "Formal form when not suggesting (honorific)": "V시지 말지 그래요?",
    "Indirect speech when requiring": "V라고/으라고 하다; *주라고 하다(x for me) *달라고 하다(for me)",
    "Indirect speech when requiring (honorific)": "V시라고/으시라고 하시다",
    "Indirect speech when requiring not to": "V지 말라고 하다",
    "Indirect speech when requiring not to (honorific)": "V시지 말라고 하시다",
    "Indirect speech when questioning": "V느냐고 하다; A냐고/으냐고 하다; N냐고/이냐고 하다; *A(있다/없다)느냐고 하다",
    "Indirect speech in past tense when questioning": "V-았/-었느냐고 하다; A-았/-었느냐고 하다; N였냐고/이었냐고 하다",
    "Indirect speech in future tense when questioning": "V-ㄹ/을 거냐고 하다",
}

class word:
    def __init__(self, name, isVerb, isAdj, isNoun, pastform, meet아어, meet으, meet으시, meet으ㄹ, meet으실, meet는, meet신):
        self.name = name
        self.isVerb = isVerb
        self.isAdj = isAdj
        self.isNoun = isNoun
        self.pastform = pastform
        self.meet아어 = meet아어
        self.meet으 = meet으
        self.meet으시 = meet으시
        self.meet으ㄹ = meet으ㄹ
        self.meet으실 = meet으실
        self.meet는 = meet는
        self.meet신 = meet신
    def partOfSpeech(self):
        print("Part of speech of", self.name, "is:")
        if self.isVerb:
            print("Verb")
        if self.isAdj:
            print("Adjective")
        if self.isNoun:
            print("Noun")
    def combination(self):
        print("Combinations of", self.name, "are:")
        print("Past form:", self.pastform)
        print("Meet 아/어:", self.meet아어)
        print("Meet 으:", self.meet으)
        print("Meet 으시:", self.meet으시)
        print("Meet 으ㄹ:", self.meet으ㄹ)
        print("Meet 으실:", self.meet으실)
        print("Meet 는:", self.meet는)
        print("Meet 신:", self.meet신)

#initialize verbs
#self, name, isVerb, isAdj, isNoun, pastform, meet아어, meet으, meet으시, meet으ㄹ, meet으실
가다 = word("가다", True, False, False, "갔다", "가", "가", "가시", "갈", "가실", "간다", "가신")
사다 = word("사다", True, False, False, "샀다", "사", "사", "사시", "살", "사실", "산다", "사신")
엽습하다 = word("엽습하다", True, False, False, "연습했다", "엽습해", "엽습하", "엽습하시", "엽습할", "엽습하실", "엽습한다", "엽습하신")
마시다 = word("마시다", True, False, False, "마셨다", "마셔", "마시", "드시", "마실", "드실", "마신다", "드신")
자다 = word("자다", True, False, False, "잤다", "자", "자", "주무시", "잘", "주무실", "잔다", "주무신")
예약하다 = word("예약하다", True, False, False, "예약했다", "예약해", "예약하", "예약하시", "예약할", "예약하실", "예약한다", "예약하신")
되다 = word("되다", True, False, False, "됬다", "돼", "되", "되시", "될", "되실", "된다", "되신")
주다 = word("주다", True, False, False, "줬다", "줘", "주", "주시", "줄", "주실", "준다", "주신")
읽다 = word("읽다", True, False, False, "읽었다", "읽어", "읽으", "읽으시", "읽을", "읽으실", "읽는다", "읽으신")
먹다 = word("먹다", True, False, False, "먹었다", "먹어", "먹으", "드시", "먹을", "드실", "먹는다", "드신")
줍다 = word("줍다", True, False, False, "주웠다", "주워", "주우", "주우시", "주울", "주우실", "줍는다", "주우신")
걷다 = word("걷다", True, False, False, "걸었다", "걸어", "걸으", "걸으시", "걸을", "걸으실", "걷는다", "걸으신")
듣다 = word("듣다", True, False, False, "들었다", "들어", "들으", "들으시", "들을", "들으실", "듣는다", "들으신")
살다 = word("살다", True, False, False, "살았다", "살아", "살", "사시", "살", "사실", "산다", "사신")
놀다 = word("놀다", True, False, False, "놀았다", "놀아", "놀", "노시", "놀", "노실", "논다", "노신")
만들다 = word("만들다", True, False, False, "만들었다", "만들어", "만들", "만드시", "만들을", "만들실", "만든다", "만드신")
입다 = word("입다", True, False, False, "입었다", "입어", "입으", "입으시", "입을", "입으실", "입는다", "입으신")
씹다 = word("씹다", True, False, False, "씹었다", "씹어", "씹으", "씹으시", "씹을", "씹으실", "씹는다", "씹으신")
받다 = word("받다", True, False, False, "받았다", "받아", "받으", "받으시", "받을", "받으실", "받는다", "받으신")
닫다 = word("닫다", True, False, False, "닫았다", "닫아", "닫으", "닫으시", "닫을", "닫으실", "닫는다", "닫으신")
싶다 = word("싶다", True, False, False, "싶었다", "싶어", "싶으", "싶으시", "싶을", "싶으실", "싶는다", "싶으신")
있다 = word("있다", True, False, False, "있었다", "있어", "있으", "계시", "있을", "계실", "있는다", "계신")
않다 = word("않다", True, False, False, "않았다", "않아", "않으", "않으시", "않을", "않으실", "않는다", "않으신")
#initialize adjectives
#self, name, isVerb, isAdj, isNoun, pastform, meet아어, meet으, meet으시, meet으ㄹ, meet으실
유명하다 = word("유명하다", False, True, False, "유명했다", "유명해", "유명하", "유명하시", "유명하", "유명하시", "유명하다", "유명하신")
복잡하다 = word("복잡하다", False, True, False, "복잡했다", "복잡해", "복잡하", "복잡하시", "복잡하", "복잡하시", "복잡하다", "복잡하신")
따뜻하다 = word("따뜻하다", False, True, False, "따뜻했다", "따뜻해", "따뜻하", "따뜻하시", "따뜻할", "따뜻하시", "따뜻하다", "따뜻하신")
비싸다 = word("비싸다", False, True, False, "비쌌다", "비싸", "비싸", "비싸시", "비쌀", "비싸시", "비싸다", "비싸신")
좋다 = word("좋다", False, True, False, "좋았다", "좋아", "좋으", "좋으시", "좋을", "좋으실", "좋다", "좋으신")
춥다 = word("춥다", False, True, False, "추웠다", "추워", "추우", "추우시", "추울", "추우시", "추운", "추우신")
맵다 = word("맵다", False, True, False, "매웠다", "매워", "매우", "매우시", "매울", "매우시", "매운", "매우신")
어렵다 = word("어렵다", False, True, False, "어려웠다", "어려워", "어려우", "어려우시", "어려울", "어려울시", "어려운", "어려우신")
멀다 = word("멀다", False, True, False, "멀었다", "멀어", "멀", "idk", "idk", "idk", "멀다", "idk")
#initialize nouns
#self, name, isVerb, isAdj, isNoun, pastform, meet아어, meet으, meet으시, meet으ㄹ, meet으실
의사 = word("의사", False, False, True, "의사", "의사", "의사", "의사", "의사", "의사", "idk", "idk")
학교 = word("학교", False, False, True, "학교", "학교", "학교", "학교", "학교", "학교", "idk", "idk")
아버지 = word("아버지", False, False, True, "아버지", "아버지", "아버지", "아버지", "아버지", "아버지", "idk", "idk")
어머니 = word("어머니", False, False, True, "어머니", "어머니", "어머니", "어머니", "어머니", "어머니", "idk", "idk")
친구 = word("친구", False, False, True, "친구", "친구", "친구", "친구", "친구", "친구", "idk", "idk")
사랑 = word("사랑", False, False, True, "사랑", "사랑", "사랑", "사랑", "사랑", "사랑", "idk", "idk")
음식 = word("음식", False, False, True, "음식", "음식", "음식", "음식", "음식", "음식", "idk", "idk")
책 = word("책", False, False, True, "책", "책", "책", "책", "책", "책", "idk", "idk")
음악 = word("음악", False, False, True, "음악", "음악", "음악", "음악", "음악", "음악", "idk", "idk")
영화 = word("영화", False, False, True, "영화", "영화", "영화", "영화", "영화", "영화", "idk", "idk")

baseforms = {
    #동사
    #x: 받침 x, o: 받침 o, ㅂ: ㅂ 불규칙, ㄷ: ㄷ 불규칙, ㄹ: ㄹ 불규칙, *: Always Regular
    "가다": "x","사다": "x", "엽습하다": "x","마시다": "x","자다":"x","예약하다": "x","되다":"x","주다":"x",
    "읽다": "o","먹다": "o","있다":"o",
    "줍다": "ㅂ",
    "걷다": "ㄷ", "듣다": "ㄷ",
    "살다": "ㄹ", "놀다": "ㄹ","만들다":"ㄹ",
    "입다": "*",
    "씹다": "*",
    "받다": "*",
    "닫다": "*",
    #형용사
    #xx: 받침 x, oo: 받침 o, ㅂㅂ: ㅂ 불규칙, ㄷㄷ: ㄷ 불규칙, ㄹㄹ: ㄹ 불규칙, **: Always Regular
    "유명하다": "xx", "복잡하다": "xx", "따뜻하다": "xx", "비싸다": "xx",
    "좋다": "oo", "있다":"oo", "싶다": "oo",
    "춥다": "ㅂㅂ", "맵다": "ㅂㅂ", "어렵다": "ㅂㅂ",

    "멀다": "ㄹㄹ",
    #명사
    #xxx: 받침 x, ooo: 받침 o, ㅂㅂㅂ: ㅂ 불규칙, ㄷㄷㄷ: ㄷ 불규칙, ㄹㄹㄹ: ㄹ 불규칙, ***: Always Regular
    "의사": "xxx", "학교": "xxx", "아버지": "xxx", "어머니": "xxx", "친구": "xxx",
    "사랑": "ooo", "음식": "ooo", "책": "ooo", "음악": "ooo", "영화": "ooo",
}

pastforms = {
    "가다": "갔다","사다": "샀다", "엽습하다": "연습했다","마시다": "마셨다","자다":"잤다","예약하다": "예약했다","되다":"됬다","주다":"줬다",
    "읽다": "읽었다","먹다": "먹었다","있다":"있었다",
    "줍다": "주웠다",
    "걷다": "걸었다", "듣다": "들었다",
    "살다": "살았다", "놀다": "놀았다","만들다":"만들었다",
    "입다": "입었다",
    "씹다": "씹었다",
    "받다": "받았다",
    "닫다": "닫았다",
    #형용사
    "유명하다": "유명했다", "복잡하다": "복잡했다", "따뜻하다": "따뜻했다", "비싸다": "비쌌다",
    "좋다": "좋았다", "있다":"있었다", "싶다": "싶었다",
    "춥다": "추웠다", "맵다": "매웠다", "어렵다": "어려웠다",
    "멀다": "멀었다"
}

testVerb = ["가다","읽다","줍다","듣다","살다","받다","먹다","마시다","있다","주다"]
testAdj = ["유명하다","좋다","춥다","멀다"]
testNoun = ["친구","사랑"]
            
meet으 = {
    "가다": "가","사다": "사", "엽습하다": "엽습하","마시다": "마시","자다":"자","예약하다": "예약하","주다":"주",
    "읽다": "읽으","먹다": "먹으",
    "줍다": "주우",
    "걷다": "걸으", "듣다": "들으",
    "살다": "살", "놀다": "놀",
    "입다": "입으",
    "씹다": "씹으",
    "받다": "받으",
    "닫다": "닫으",
    #형용사
    "유명하다": "유명하", "복잡하다": "복잡하", "따뜻하다": "따뜻하", "비싸다":"비싸",
    "좋다": "좋으", "있다":"있으", "싶다": "싶으",
    "춥다": "추우", "맵다": "매우",
    "멀다": "idk"
}

meet으시 = {
    "가다": "가시","사다": "사시", "엽습하다": "엽습하시","마시다": "드시","자다":"주무시","예약하다": "예약하시","주다":"주시",
    "읽다": "읽으시","먹다": "드시",
    "줍다": "주우시",
    "걷다": "걸으시", "듣다": "들으시",
    "살다": "사시", "놀다": "노시",
    "입다": "입으시",
    "씹다": "씹으시",
    "받다": "받으시",
    "닫다": "닫으시",
    #형용사
    "유명하다": "유명하시", "복잡하다": "복잡하시", "따뜻하다": "따뜻하시", "비싸다":"비싸시",
    "좋다": "좋으시","있다":"있으시", "싶다":"싶으시",
    "춥다": "추우시", "맵다": "매우시",
    "멀다": "idk"
}

meet으ㄹ = {
    "가다": "갈","사다": "살", "엽습하다": "엽습할","마시다": "마실","자다":"잘","예약하다": "예약할","주다":"줄",
    "읽다": "읽을","먹다": "먹을",
    "줍다": "주울",
    "걷다": "걸을", "듣다": "들을",
    "살다": "살", "놀다": "놀",
    "입다": "입을",
    "씹다": "씹을",
    "받다": "받을",
    "닫다": "닫을",
}

meet으실 = {
    "가다": "가실","사다": "사실", "엽습하다": "엽습하실","마시다": "드실","자다":"주무실","예약하다": "예약하실","주다":"주실",
    "읽다": "읽으실","먹다": "드실",
    "줍다": "주우실",
    "걷다": "걸으실", "듣다": "들으실",
    "살다": "사실", "놀다": "노실",
    "입다": "입으실",
    "씹다": "씹으실",
    "받다": "받으실",
    "닫다": "닫으실",
}

meet는 = {
    "하다": "한","가다": "간", "오다": "온", "자다": "잔", 
    "먹다": "먹는","읽다":"읽는",
    "줍다": "주운",
    "듣다": "듣는",
    "살다": "산","놀다": "논",
    "입다": "입는",
    "씹다": "씹는",
    "받다": "받는",
    "마시다": "마시는",
    "있다": "있는",
    "주다": "주는",
}

meet으신 = {
    "하다": "하신","가다": "간", "오다": "온", "자다": "잔", "주무시다":"주무신",
    "먹다": "먹으신","읽다":"읽으신",
    "줍다": "주우신",
    "듣다": "들으신",
    "살다": "사신","놀다": "노신",
    "입다": "입으신",
    "씹다": "씹으신",
    "받다": "받으신",
    "마시다": "드시신",
    "있다": "계신",
    "주다": "주신",
}
    

def printl(input, length):
    for i in range(length):
        print(input, end="")
    print()

def getChar(hangul):
    print("Code of ", hangul, "is ", ord(hangul))

def searchCode():
    hangulinput = input("Enter the hangul you want to convert to number: ")
    while hangulinput != ".":
        getChar(hangulinput)
        hangulinput = input("Enter the hangul you want to convert to number: ")

def printSimilar(base):
    print("Similar bases:", end="")
    for x in baseforms:
        if baseforms[x] == baseforms[base] and base != x:
            print(x,end=" ")
    print()

def 거예요(verb):
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -ㄹ 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "o":
            print("(받침 o: -을 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "ㅂ":
            print("(ㅂ 불규칙: -울 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ을 거예요)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "ㄹ":
            print("(ㄹ 불규칙: -거예요 ㄹ+으=drop으)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case "*":
            print("(Always Regular)")
            print("V-(으)ㄹ 거예요 of", verb, ":", meet으ㄹ[verb], "거예요.")
        case default:
            print("A verb is needed for 거예요.")
    print("존댓말: ")
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "o":
            print("(받침 o: -으실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "ㅂ":
            print("(ㅂ 불규칙: -우실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ으실 거예요)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "ㄹ":
            print("(ㄹ 불규칙: -실 거예요 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case "*":
            print("(Always Regular)")
            print("V-(으)실 거예요 of", verb, ":", meet으실[verb], "거예요.")
        case default:
            print("A verb is needed for 거예요.")
    printl(LINECHAR,5)

def 으면(adjverb):
    match(baseforms[adjverb]):
        case "x"|"xx":
            print("(받침 x: -면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "o"|"oo":
            print("(받침 o: -으면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "ㅂ"|"ㅂㅂ":
            print("(ㅂ 불규칙: -우면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "ㄷ"|"ㄷㄷ":
            print("(ㄷ 불규칙: -ㄹ으면)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "ㄹ"|"ㄹㄹ":
            print("(ㄹ 불규칙: -면 ㄹ+으=drop으)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case "*"|"**":
            print("(Always Regular)")
            print("A/V-(으)면 of", adjverb, ":", meet으[adjverb]+"면")
        case default:
            print("A verb or an adj. is needed for 으면.")
    print("존댓말: ")
    match(baseforms[adjverb]):
        case "x"|"xx":
            print("(받침 x: -시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "o"|"oo":
            print("(받침 o: -으시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "ㅂ"|"ㅂㅂ":
            print("(ㅂ 불규칙: -우시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "ㄷ"|"ㄷㄷ":
            print("(ㄷ 불규칙: -ㄹ으시면)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "ㄹ"|"ㄹㄹ":
            print("(ㄹ 불규칙: -시면 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case "*"|"**":
            print("(Always Regular)")
            print("A/V-(으)시면 of", adjverb, ":", meet으시[adjverb]+"면")
        case default:
            print("A verb or an adj. is needed for 으면.")
    printl(LINECHAR,5)

def 수_있다(verb):
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -ㄹ 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "o":
            print("(받침 o: -을 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "ㅂ":
            print("(ㅂ 불규칙: -울 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ을 수 있다)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "ㄹ":
            print("(ㄹ 불규칙: -수 있다 ㄹ+으=drop으)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case "*":
            print("(Always Regular)")
            print("V-(으)ㄹ 수 있다 of", verb, ":", meet으ㄹ[verb], "수 있다.")
        case default:
            print("A verb is needed for 수 있다.")
    print("존댓말: ")
    match(baseforms[verb]):
        case "x":
            print("(받침 x: -실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "o":
            print("(받침 o: -으실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "ㅂ":
            print("(ㅂ 불규칙: -우실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "ㄷ":
            print("(ㄷ 불규칙: -ㄹ으실 수 있다)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "ㄹ":
            print("(ㄹ 불규칙: -실 수 있다 ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case "*":
            print("(Always Regular)")
            print("V-(으)실 수 있다 of", verb, ":", meet으실[verb], "수 있다.")
        case default:
            print("A verb is needed for 수 있다.")
    printl(LINECHAR,5)

def 문어체(adjverbnoun):
    match(baseforms[adjverbnoun]):
        case "x":
            print("V-ㄴ다/는다 of", adjverbnoun, ":", meet는[adjverbnoun]+"다")
            print("(받침 x: -ㄴ다)")
            print("V-ㄴ다/는다(과거) of", adjverbnoun, ":", pastforms[adjverbnoun]+"다")
            print("(Past tense unchanged)")
        case "o"|"ㅂ"|"ㄷ":
            print("V-ㄴ다/는다 of", adjverbnoun, ":", meet는[adjverbnoun]+"다")
            print("(받침 o: -는다)")
            print("V-ㄴ다/는다(과거) of", adjverbnoun, ":", pastforms[adjverbnoun]+"다")
            print("(Past tense unchanged)")
        case "ㄹ":
            print("V-ㄴ다/는다 of", adjverbnoun, ":", meet는[adjverbnoun]+"다")
            print("(ㄹ 불규칙: ㄹ+는=>dropㄹ = ㄴleft)")
            print("V-ㄴ다/는다(과거) of", adjverbnoun, ":", pastforms[adjverbnoun]+"다")
            print("(Past tense unchanged)")
        case "*":
            print("V-ㄴ다/는다 of", adjverbnoun, ":", meet는[adjverbnoun]+"다")
            print("(Always Regular)")
            print("V-ㄴ다/는다(과거) of", adjverbnoun, ":", pastforms[adjverbnoun]+"다")
            print("(Past tense unchanged)")
        case "xx"| "oo"|"ㅂㅂ"|"ㄷㄷ"|"ㄹㄹ"|"**":
            print("ADJ-다 of", adjverbnoun, ":", adjverbnoun)
            print("ADJ-다(과거) of", adjverbnoun, ":", pastforms[adjverbnoun])
            print("(Past tense unchanged)")
        #to be implemented
        case default:
            print("Not yet implemented.")
    print("V-(으)신다 of", adjverbnoun, ":", meet으신[adjverbnoun]+"다")
    match(baseforms[adjverbnoun]):
        case "x":
            print("(받침 x: -신다)")
        case "o"|"ㅂ"|"ㄷ":
            print("(받침 o: -으신다)")
        case "ㄹ":
            print("(ㄹ 불규칙: ㄹ+으=drop으 ㄹ+ㅂ/ㄴ/ㅅ=dropㄹ)")
        case "*"|"**":
            print("(Always Regular)")
        case default:
            print("Not yet implemented.")
    printl(LINECHAR,5)

def sumVerb(word):
    printl("^",30)
    print("——————————————————")
    print("| Tenses of",word,"|")
    print("——————————————————")

    printSimilar(word)
    printl('=',5)

    거예요(word)
    으면(word)
    수_있다(word)

    printl("v",30)
    print("\n")

def sumGrammar():
    choice = 1
    while(choice != 0):
        print("1. Talking about future plans 거예요")
        print("2. If/When 으면")
        print("3. Can/Be able to 수_있")
        print("4. Formal form 문어체")
        print("0. Exit")
        choice = int(input("Enter the number of the grammar you want to learn: "))
        if choice == 1:
            printl(LINECHAR,5)
            print("Talking about future plans 거예요")
            printl(LINECHAR,5)
            for verb in testVerb:
                거예요(verb)
            printl(LINECHAR,5)
        elif choice == 2:
            printl(LINECHAR,5)
            print("If/When 으면")
            printl(LINECHAR,5)
            for verb in testVerb:
                으면(verb)
            for adj in testAdj:
                으면(adj)
            printl(LINECHAR,5)
        elif choice == 3:
            printl(LINECHAR,5)
            print("Can/Be able to 수_있다")
            printl(LINECHAR,5)
            for verb in testVerb:
                수_있다(verb)
            printl(LINECHAR,5)
        elif choice == 4:
            printl(LINECHAR,5)
            print("Formal form 문어체")
            printl(LINECHAR,5)
            for verb in testVerb:
                문어체(verb)
            for adj in testAdj:
                문어체(adj)
            for noun in testNoun:
                문어체(noun)
            printl(LINECHAR,5)
        elif choice == 0:
            break
        else:
            print("Invalid input. Please try again.")
            printl(LINECHAR,5)

def read_file_line_by_line(file_path):
    questions = []
    answers = [] 
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
            for i in range(len(lines)):
                if i % 2 == 0:
                    questions.append(lines[i].strip())
                else:
                    answers.append(lines[i].strip())
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    return questions, answers


def practice(file_path):
    questions, answers = read_file_line_by_line(file_path) 
    corrects = [0] * len(questions)
    wrongs = [0] * len(questions)  
    answered = 0
    #generate random question 
    while (answered < len(questions)):
        qIndex = random.randint(0, len(questions)-1)
        while(corrects[qIndex] > 0):
            qIndex = random.randint(0, len(questions)-1)
        print(questions[qIndex])
        #get user input
        answer = input("Enter your answer: ")
        while answer == "":
            answer = input("Enter your answer: ")
        #print user input
        split = questions[qIndex].split('-')
        print(split[0]+answer+split[1])
        #check answer
        if answer == answers[qIndex]:
            corrects[qIndex] += 1
            answered += 1   
        else:
            print("Correct answer: ", answers[qIndex])
            wrongs[qIndex] += 1
        #print results
        sumCorr, sumWrong = 0, 0
        for i in range(len(questions)):
            sumCorr += corrects[i]
            sumWrong += wrongs[i]
        print("#correct: ", sumCorr, "#wrong: ", sumWrong, "Questions: ", answered, "/", len(questions))
    #print the answers of the wrong questions
    for wIndex in range(len(questions)):
        if wrongs[wIndex] > 0:
            split = questions[wIndex].split('-')
            print("Redo Question:\n",wIndex, questions[wIndex])
            redoInput = input()
            print("MyAns: ", split[0]+redoInput+split[1])

            print("Answer:", split[0]+answers[wIndex]+split[1])
#run
# sumVerb("가다")
# sumVerb("자다")
# sumVerb("먹다")
# sumVerb("줍다")
# sumVerb("듣다")
# sumVerb("살다")
# sumVerb("받다")
# sumVerb("입다")
# sumVerb("유명하다")
#sumGrammar()
file_path = input("Enter the file path: ")
practice(file_path)
# Out:
# 마크: "지성과 천러가 잘 어울려요." 마크가 지성과 천러가 잘 -다고 했어요.
# 마크: "지성과 천러가 잘 어울려요." 마크가 지성과 천러가 잘 어울린다고 했어요.
# #correct:  1 #wrong:  0 Questions:  1 / 114
# 추칙이 -(틀리다)다.
# 추칙이 틀린(틀리다)다.
# Correct answer:  틀리
# #correct:  1 #wrong:  1 Questions:  1 / 114
# 의견- 반대하다/찬성하다.
# 의견을 반대하다/찬성하다.
# Correct answer:  에
# #correct:  1 #wrong:  2 Questions:  1 / 114
# 창문- 열려 있어요.
# 창문이 열려 있어요.
# #correct:  2 #wrong:  2 Questions:  2 / 114
# 천러 씨 차- 지성 씨 차가 뒤에서 받았대.
# 천러 씨 차를 지성 씨 차가 뒤에서 받았대.
# #correct:  3 #wrong:  2 Questions:  3 / 114
# 다른 회사- 옮긴대요.
# 다른 회사로 옮긴대요.
# #correct:  4 #wrong:  2 Questions:  4 / 114
# 한국 으식 중에서 갈비를 아주 좋아하는데 소갈비는 비싸서 자주 먹지 못 -(하다)다.
# 한국 으식 중에서 갈비를 아주 좋아하는데 소갈비는 비싸서 자주 먹지 못 한(하다)다.
# #correct:  5 #wrong:  2 Questions:  5 / 114
# 어제 회사- 지각했다.
# 어제 회사에 지각했다.
# #correct:  6 #wrong:  2 Questions:  6 / 114
# 저거는 사고- 난 차.
# 저거는 사고가 난 차.
# #correct:  7 #wrong:  2 Questions:  7 / 114
# 불- 꺼졌다.
# 불이 꺼졌다.
# #correct:  8 #wrong:  2 Questions:  8 / 114
# 부산은 여기- 너무 멀잖아.
# 부산은 여기에 너무 멀잖아.
# #correct:  9 #wrong:  2 Questions:  9 / 114
# 축재- 준비되다.
# 축재가 준비되다.
# Correct answer:  를
# #correct:  9 #wrong:  3 Questions:  9 / 114
# 푹솔가 -다
# 푹솔가 내리다
# #correct:  10 #wrong:  3 Questions:  10 / 114
# 고향- 들어갈 것 같은데요.
# 고향으로 들어갈 것 같은데요.
# #correct:  11 #wrong:  3 Questions:  11 / 114
# 지성 씨가 사람들- 인기가 많는 것 같아.
# 지성 씨가 사람들한테 인기가 많는 것 같아.
# #correct:  12 #wrong:  3 Questions:  12 / 114
# 집이 사람이 없어서 문이 - 있어요.
# 집이 사람이 없어서 문이 닫혀 있어요.
# #correct:  13 #wrong:  3 Questions:  13 / 114
# 불- 껐다.
# 불을 껐다.
# #correct:  14 #wrong:  3 Questions:  14 / 114
# 이 허리띠는 요즘 -(유행하다)다.
# 이 허리띠는 요즘 유행한(유행하다)다.
# #correct:  15 #wrong:  3 Questions:  15 / 114
# -(달다) 케이크
# 단(달다) 케이크
# #correct:  16 #wrong:  3 Questions:  16 / 114
# 웨이비는 산- 내려와서 점심을 먹었다.
# 웨이비는 산에 내려와서 점심을 먹었다.
# Correct answer:  에서
# #correct:  16 #wrong:  4 Questions:  16 / 114
# 소희: "여기서 학교까지 멀어요?" 소희가 여기서 학교까지 -(멀다)고 했어요.
# 소희: "여기서 학교까지 멀어요?" 소희가 여기서 학교까지 머냐(멀다)고 했어요.
# #correct:  17 #wrong:  4 Questions:  17 / 114
# 여기가 -(맞다) 것 같은데...
# 여기가 맞는(맞다) 것 같은데...
# #correct:  18 #wrong:  4 Questions:  18 / 114
# 저거는 사고- 당한 차.
# 저거는 사고를 당한 차.
# #correct:  19 #wrong:  4 Questions:  19 / 114
# 보는 사람이 없는데 거실에 있는 텔레비전은 - 있었다.
# 보는 사람이 없는데 거실에 있는 텔레비전은 껴져 있었다.
# #correct:  20 #wrong:  4 Questions:  20 / 114
# 나: "선생님, 한국어 좀 가르쳐 주세요." 나는 선생님께 한국어 좀 가르쳐 -(주다)고 했서요.
# 나: "선생님, 한국어 좀 가르쳐 주세요." 나는 선생님께 한국어 좀 가르쳐 달라(주다)고 했서요.
# #correct:  21 #wrong:  4 Questions:  21 / 114
# 우리 할머니께서는 -(젊다)때 샌프란시스코에 사신 적이 있다고 하셨다.
# 우리 할머니께서는 젊을(젊다)때 샌프란시스코에 사신 적이 있다고 하셨다.
# Correct answer:  젊으셨을
# #correct:  21 #wrong:  5 Questions:  21 / 114
# 대학- 입학했다
# 대학에 입학했다
# #correct:  22 #wrong:  5 Questions:  22 / 114
# 정전이 -다
# 정전이 되다
# #correct:  23 #wrong:  5 Questions:  23 / 114
# 살- 빼다
# 살를 빼다
# Correct answer:  을
# #correct:  23 #wrong:  6 Questions:  23 / 114
# 유타:"제 머리가 너무 길어요?" 유타 씨는 자기 머리가 너무 -고 했다.
# 유타:"제 머리가 너무 길어요?" 유타 씨는 자기 머리가 너무 기냐고 했다.
# Correct answer:  기냐고
# #correct:  23 #wrong:  7 Questions:  23 / 114
# 두 아이의 엄마가 -다.
# 두 아이의 엄마가 되었다.
# #correct:  24 #wrong:  7 Questions:  24 / 114
# 사위-다
# 사위하다
# #correct:  25 #wrong:  7 Questions:  25 / 114
# 다음 주말에 우리는 또 산에 갈 거예요. 다음 주말에 우리는 또 산에 갈 -다.
# 다음 주말에 우리는 또 산에 갈 거예요. 다음 주말에 우리는 또 산에 갈 것이다.
# #correct:  26 #wrong:  7 Questions:  26 / 114
# 이 인형가 커 -(보이다)다.
# 이 인형가 커 보인(보이다)다.
# #correct:  27 #wrong:  7 Questions:  27 / 114
# 마크는 오늘 일하지 -(않다)고 했어요.
# 마크는 오늘 일하지 않는(않다)고 했어요.
# Correct answer:  않는다
# #correct:  27 #wrong:  8 Questions:  27 / 114
# 시계가 벽에 - 있어요.
# 시계가 벽에 걸려 있어요.
# Correct answer:  결려
# #correct:  27 #wrong:  9 Questions:  27 / 114
# 시계가 벽에 - 있어요.
# 시계가 벽에 걸려 있어요.
# Correct answer:  결려
# #correct:  27 #wrong:  10 Questions:  27 / 114
# 천러 씨 차를 지성 씨 차가 뒤- 받았대.
# 천러 씨 차를 지성 씨 차가 뒤에서 받았대.
# #correct:  28 #wrong:  10 Questions:  28 / 114
# 구두를 -고 계시는 분세요.
# 구두를 신고 계시는 분세요.
# #correct:  29 #wrong:  10 Questions:  29 / 114
# 안경을 -고 계시는 분세요.
# 안경을 쓰고 계시는 분세요.
# #correct:  30 #wrong:  10 Questions:  30 / 114
# 전쟁- 나다
# 전쟁이 나다
# #correct:  31 #wrong:  10 Questions:  31 / 114
# 지진- 나다
# 지진이 나다
# #correct:  32 #wrong:  10 Questions:  32 / 114
# 어머니- 편지를 보내요.
# 어머니께 편지를 보내요.
# #correct:  33 #wrong:  10 Questions:  33 / 114
# 불- 나다
# 불이 나다
# #correct:  34 #wrong:  10 Questions:  34 / 114
# 시계가 벽에 - 있어요.
# 시계가 벽에 결려 있어요.
# #correct:  35 #wrong:  10 Questions:  35 / 114
# 해찬 씨는 -(자다)데 재민 씨는 고부해요.
# 해찬 씨는 자는(자다)데 재민 씨는 고부해요.
# #correct:  36 #wrong:  10 Questions:  36 / 114
# 물가가 많이 -(오르다)서 먹고 싶은 것을 자 사지 못한다.
# 물가가 많이 올려(오르다)서 먹고 싶은 것을 자 사지 못한다.
# Correct answer:  올라
# #correct:  36 #wrong:  11 Questions:  36 / 114
# 창문이 - 있어요.
# 창문이 열려 있어요.
# #correct:  37 #wrong:  11 Questions:  37 / 114
# 의견- 반대하다/찬성하다.
# 의견에 반대하다/찬성하다.
# #correct:  38 #wrong:  11 Questions:  38 / 114
# 주차장- 주차하면 안 된다.
# 주차장에 주차하면 안 된다.
# #correct:  39 #wrong:  11 Questions:  39 / 114
# 사쿠: "코트가 두꺼워요?" 사쿠 씨가 코트가 -(두껍다)고 했다.
# 사쿠: "코트가 두꺼워요?" 사쿠 씨가 코트가 두꺼우냐(두껍다)고 했다.
# #correct:  40 #wrong:  11 Questions:  40 / 114
# 이 치마가 정우 씨- 잘 어울렸다.
# 이 치마가 정우 씨한테 잘 어울렸다.
# #correct:  41 #wrong:  11 Questions:  41 / 114
# 축재- 준비하다.
# 축재가 준비하다.
# #correct:  42 #wrong:  11 Questions:  42 / 114
# 웨이비는 산- 내려와서 점심을 먹었다.
# 웨이비는 산에서 내려와서 점심을 먹었다.
# #correct:  43 #wrong:  11 Questions:  43 / 114
# 지성: "지금 뭘 만들어요?" 지성 씨가 지금 뭘 -(만들다)고 했다.
# 지성: "지금 뭘 만들어요?" 지성 씨가 지금 뭘 만드느냐(만들다)고 했다.
# #correct:  44 #wrong:  11 Questions:  44 / 114
# 재희 씨- 들었는데, 리쿠 씨가 지금...
# 재희 씨한테 들었는데, 리쿠 씨가 지금...
# #correct:  45 #wrong:  11 Questions:  45 / 114
# 교통 사고가 -(나다) 것 같다
# 교통 사고가 난(나다) 것 같다
# #correct:  46 #wrong:  11 Questions:  46 / 114
# 우리 할머니께서는 -(젊다)때 샌프란시스코에 사신 적이 있다고 하셨다.
# 우리 할머니께서는 젊으셨을(젊다)때 샌프란시스코에 사신 적이 있다고 하셨다.
# #correct:  47 #wrong:  11 Questions:  47 / 114
# 도독- 맞은 것 같아요.
# 도독을 맞은 것 같아요.
# #correct:  48 #wrong:  11 Questions:  48 / 114
# 병원- 입원했다.
# 병원에 입원했다.
# #correct:  49 #wrong:  11 Questions:  49 / 114
# 다른 회사로 -(옮기다)대요.
# 다른 회사로 옮긴(옮기다)대요.
# #correct:  50 #wrong:  11 Questions:  50 / 114
# 줄업 후에 회사- 취직하고 싶다.
# 줄업 후에 회사에 취직하고 싶다.
# #correct:  51 #wrong:  11 Questions:  51 / 114
# 지성 씨가 또 -(서다) 있어요.
# 지성 씨가 또 서(서다) 있어요.
# #correct:  52 #wrong:  11 Questions:  52 / 114
# 약속을 안 -(지키다) 사람
# 약속을 안 지킨(지키다) 사람
# Correct answer:  지키는
# #correct:  52 #wrong:  12 Questions:  52 / 114
# 같은 대학- 다니는 남자친구가 있다.
# 같은 대학에 다니는 남자친구가 있다.
# #correct:  53 #wrong:  12 Questions:  53 / 114
# 비행기 시간- 늦였어요.
# 비행기 시간에 늦였어요.
# #correct:  54 #wrong:  12 Questions:  54 / 114
# 술을 -지 않을 거에요.
# 술을 마시지 않을 거에요.
# #correct:  55 #wrong:  12 Questions:  55 / 114
# 친구- 편지를 보내요.
# 친구한테 편지를 보내요.
# #correct:  56 #wrong:  12 Questions:  56 / 114
# 지성이는 낯- 거리다.
# 지성이는 낯을 거리다.
# #correct:  57 #wrong:  12 Questions:  57 / 114
# 재민 씨가 잠채가 -(맛있다)냐고 물었어요.
# 재민 씨가 잠채가 맛있느(맛있다)냐고 물었어요.
# #correct:  58 #wrong:  12 Questions:  58 / 114
# -(차갑다) 물
# 차가운(차갑다) 물
# #correct:  59 #wrong:  12 Questions:  59 / 114
# 어디- 출장을 가셨는지 아세요?
# 어디로 출장을 가셨는지 아세요?
# #correct:  60 #wrong:  12 Questions:  60 / 114
# 리쿠 씨가 다른 약속이 있어서 못 -(가다)고 했어요.
# 리쿠 씨가 다른 약속이 있어서 못 간(가다)고 했어요.
# Correct answer:  간다
# #correct:  60 #wrong:  13 Questions:  60 / 114
# 하늘이 -(파랗다)니까
# 하늘이 파라(파랗다)니까
# #correct:  61 #wrong:  13 Questions:  61 / 114
# 비가 -(멈추다) 때까지 기다리면 돼요.
# 비가 멈출(멈추다) 때까지 기다리면 돼요.
# #correct:  62 #wrong:  13 Questions:  62 / 114
# 태풍이 -다
# 태풍이 오다
# #correct:  63 #wrong:  13 Questions:  63 / 114
# 마크: "사과가 착해요." 마크가 사과가 -다고 했어요.
# 마크: "사과가 착해요." 마크가 사과가 착하다고 했어요.
# #correct:  64 #wrong:  13 Questions:  64 / 114
# 얼굴이 -(빨갛다)면
# 얼굴이 빨개(빨갛다)면
# Correct answer:  빨가
# #correct:  64 #wrong:  14 Questions:  64 / 114
# 재민 씨가 밥을 먹을 때 의자에 -(앉다) 있어요.
# 재민 씨가 밥을 먹을 때 의자에 앚아(앉다) 있어요.
# Correct answer:  앉아
# #correct:  64 #wrong:  15 Questions:  64 / 114
# 저기 -(졸리다) 학생이 있다.
# 저기 졸린(졸리다) 학생이 있다.
# Correct answer:  졸리는
# #correct:  64 #wrong:  16 Questions:  64 / 114
# 커피를 -(마시다) 극장에 갔어요.
# 커피를 마시는(마시다) 극장에 갔어요.
# Correct answer:  마시고
# #correct:  64 #wrong:  17 Questions:  64 / 114
# 불- 내다
# 불을 내다
# #correct:  65 #wrong:  17 Questions:  65 / 114
# 도영 씨가 무슨 음악을 -(듣다)고 했다.
# 도영 씨가 무슨 음악을 듣느냐고(듣다)고 했다.
# #correct:  66 #wrong:  17 Questions:  66 / 114
# 리쿠 씨가 다른 약속이 있어서 못 -(가다)고 했어요.
# 리쿠 씨가 다른 약속이 있어서 못 간다(가다)고 했어요.
# #correct:  67 #wrong:  17 Questions:  67 / 114
# 책이 책상 위에 - 있어요.
# 책이 책상 위에 넣여 있어요.
# Correct answer:  놓여
# #correct:  67 #wrong:  18 Questions:  67 / 114
# 홍수- 나다
# 홍수가 나다
# #correct:  68 #wrong:  18 Questions:  68 / 114
# 책- 책상 위에 놓았어요.
# 책이 책상 위에 놓았어요.
# Correct answer:  을
# #correct:  68 #wrong:  19 Questions:  68 / 114
# 책이 책상 위에 - 있어요.
# 책이 책상 위에 놓여 있어요.
# #correct:  69 #wrong:  19 Questions:  69 / 114
# 점심 먹- 어디로 갈까요?
# 점심 먹으러 어디로 갈까요?
# #correct:  70 #wrong:  19 Questions:  70 / 114
# 유타:"제 머리가 너무 길어요?" 유타 씨는 자기 머리가 너무 -고 했다.
# 유타:"제 머리가 너무 길어요?" 유타 씨는 자기 머리가 너무 기냐고고 했다.
# #correct:  71 #wrong:  19 Questions:  71 / 114
# 가방을 -고 계시는 분세요.
# 가방을 들고 계시는 분세요.
# #correct:  72 #wrong:  19 Questions:  72 / 114
# 과일을 -(씻다)서 먹어.
# 과일을 씻어(씻다)서 먹어.
# #correct:  73 #wrong:  19 Questions:  73 / 114
# 천러 씨 차를 지성 씨 차- 뒤에서 받았대.
# 천러 씨 차를 지성 씨 차가 뒤에서 받았대.
# #correct:  74 #wrong:  19 Questions:  74 / 114
# 예전에 음악을 많이 -(듣다) 것 같아요.
# 예전에 음악을 많이 들은(듣다) 것 같아요.
# #correct:  75 #wrong:  19 Questions:  75 / 114
# 중학교- 퇴학했다
# 중학교를 퇴학했다
# #correct:  76 #wrong:  19 Questions:  76 / 114
# 친구들- 너무 보고 싶어서 ㅇㅇㅇ.
# 친구들한테 너무 보고 싶어서 ㅇㅇㅇ.
# Correct answer:  이
# #correct:  76 #wrong:  20 Questions:  76 / 114
# 저기 -(졸다) 학생이 있다.
# 저기 조는(졸다) 학생이 있다.
# #correct:  77 #wrong:  20 Questions:  77 / 114
# 살- 빠지다
# 살이 빠지다
# #correct:  78 #wrong:  20 Questions:  78 / 114
# 마크: "김밥을 만들었어요?" 마크 씨가 김밥을 -(만들다)고 했다.
# 마크: "김밥을 만들었어요?" 마크 씨가 김밥을 만들었느냐(만들다)고 했다.
# #correct:  79 #wrong:  20 Questions:  79 / 114
# 나는 항상 오후 수업 시간에는 -(졸다)다.
# 나는 항상 오후 수업 시간에는 존(졸다)다.
# #correct:  80 #wrong:  20 Questions:  80 / 114
# 이거를 많이 쓰면 돈이 -(들다) 것 같아.
# 이거를 많이 쓰면 돈이 드는(들다) 것 같아.
# #correct:  81 #wrong:  20 Questions:  81 / 114
# 추칙이 -(틀리다)다.
# 추칙이 틀리(틀리다)다.
# #correct:  82 #wrong:  20 Questions:  82 / 114
# 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 -요."
# 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 죄송한데요."
# Correct answer:  죄소하대
# #correct:  82 #wrong:  21 Questions:  82 / 114
# 얼굴이 -(빨갛다)면
# 얼굴이 빨가(빨갛다)면
# #correct:  83 #wrong:  21 Questions:  83 / 114
# 푹솔이 -다
# 푹솔이 내리다
# #correct:  84 #wrong:  21 Questions:  84 / 114
# 감기- 생강차가 좋다고 들었어요
# 감기에 생강차가 좋다고 들었어요
# #correct:  85 #wrong:  21 Questions:  85 / 114
# 재민 씨는 오늘 바쁘지 -(않다)고 했어요.
# 재민 씨는 오늘 바쁘지 않다(않다)고 했어요.
# #correct:  86 #wrong:  21 Questions:  86 / 114
# 반지를 -고 계시는 분세요.
# 반지를 끼고 계시는 분세요.
# #correct:  87 #wrong:  21 Questions:  87 / 114
# 살- 빼다
# 살을 빼다
# #correct:  88 #wrong:  21 Questions:  88 / 114
# 시계를 -고 계시는 분세요.
# 시계를 차고 계시는 분세요.
# #correct:  89 #wrong:  21 Questions:  89 / 114
# 호리띠를 -고 계시는 분세요.
# 호리띠를 하고 계시는 분세요.
# #correct:  90 #wrong:  21 Questions:  90 / 114
# 도독- 든 것 같아요.
# 도독을 든 것 같아요.
# Correct answer:  이
# #correct:  90 #wrong:  22 Questions:  90 / 114
# 책- 책상 위에 놓았어요.
# 책을 책상 위에 놓았어요.
# #correct:  91 #wrong:  22 Questions:  91 / 114
# 축재- 준비되다.
# 축재를 준비되다.
# #correct:  92 #wrong:  22 Questions:  92 / 114
# 승객 김 모 씨가 지하졀 선로 - 떨어졌다.
# 승객 김 모 씨가 지하졀 선로 위에 떨어졌다.
# #correct:  93 #wrong:  22 Questions:  93 / 114
# -(재미있다) 사람
# 재미있는(재미있다) 사람
# #correct:  94 #wrong:  22 Questions:  94 / 114
# 마크는 오늘 일하지 -(않다)고 했어요.
# 마크는 오늘 일하지 않는다(않다)고 했어요.
# #correct:  95 #wrong:  22 Questions:  95 / 114
# 주사- 맞다
# 주사에 맞다
# Correct answer:  를
# #correct:  95 #wrong:  23 Questions:  95 / 114
# 가까운 데- 가요.
# 가까운 데로 가요.
# #correct:  96 #wrong:  23 Questions:  96 / 114
# 주사- 맞다
# 주사를 맞다
# #correct:  97 #wrong:  23 Questions:  97 / 114
# 부무님께서는 다음 달에 한국에 -(오다)려고 하신다.
# 부무님께서는 다음 달에 한국에 오(오다)려고 하신다.
# #correct:  98 #wrong:  23 Questions:  98 / 114
# 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 -요."
# 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 죄송하데요."
# Correct answer:  죄소하대
# #correct:  98 #wrong:  24 Questions:  98 / 114
# 경제학 공부는 좀 -(어럽다)데 재미있다.
# 경제학 공부는 좀 어려운(어럽다)데 재미있다.
# #correct:  99 #wrong:  24 Questions:  99 / 114
# 아침에 빵- 우유를 먹었다.
# 아침에 빵과 우유를 먹었다.
# #correct:  100 #wrong:  24 Questions:  100 / 114
# 도독- 든 것 같아요.
# 도독이 든 것 같아요.
# #correct:  101 #wrong:  24 Questions:  101 / 114
# 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 -요."
# 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 죄소하대요."
# #correct:  102 #wrong:  24 Questions:  102 / 114
# 친구들- 너무 보고 싶어서 ㅇㅇㅇ.
# 친구들이 너무 보고 싶어서 ㅇㅇㅇ.
# #correct:  103 #wrong:  24 Questions:  103 / 114
# 물가가 많이 -(오르다)서 먹고 싶은 것을 자 사지 못한다.
# 물가가 많이 올라(오르다)서 먹고 싶은 것을 자 사지 못한다.
# #correct:  104 #wrong:  24 Questions:  104 / 114
# 커피를 -(마시다) 극장에 갔어요.
# 커피를 마시고(마시다) 극장에 갔어요.
# #correct:  105 #wrong:  24 Questions:  105 / 114
# 이 영화는 -(재미있다)다
# 이 영화는 재미있는(재미있다)다
# #correct:  106 #wrong:  24 Questions:  106 / 114
# 도영 씨가 또 침대에 -(눕다) 있어요.
# 도영 씨가 또 침대에 누워(눕다) 있어요.
# #correct:  107 #wrong:  24 Questions:  107 / 114
# 재민 씨가 밥을 먹을 때 의자에 -(앉다) 있어요.
# 재민 씨가 밥을 먹을 때 의자에 앉(앉다) 있어요.
# Correct answer:  앉아
# #correct:  107 #wrong:  25 Questions:  107 / 114
# 어제 아뻐지는 불고기를 드시지 -(않다)요.
# 어제 아뻐지는 불고기를 드시지 않으셨어(않다)요.
# #correct:  108 #wrong:  25 Questions:  108 / 114
# 마음- 안 들면 바꾸면 돼.
# 마음에 안 들면 바꾸면 돼.
# #correct:  109 #wrong:  25 Questions:  109 / 114
# 재민 씨가 밥을 먹을 때 의자에 -(앉다) 있어요.
# 재민 씨가 밥을 먹을 때 의자에 앉아(앉다) 있어요.
# #correct:  110 #wrong:  25 Questions:  110 / 114
# 약속을 안 -(지키다) 사람
# 약속을 안 지키는(지키다) 사람
# #correct:  111 #wrong:  25 Questions:  111 / 114
# 저기 -(졸리다) 학생이 있다.
# 저기 졸리는(졸리다) 학생이 있다.
# #correct:  112 #wrong:  25 Questions:  112 / 114
# 기름 값이 -(들다)다.
# 기름 값이 든(들다)다.
# #correct:  113 #wrong:  25 Questions:  113 / 114
# 케이크 위에는 '생일 축하해'라는 글이 - 있어요.
# 케이크 위에는 '생일 축하해'라는 글이 쓰여 있어요.
# #correct:  114 #wrong:  25 Questions:  114 / 114
# Redo Question:
#  9 친구들- 너무 보고 싶어서 ㅇㅇㅇ.
# Answer: 친구들이 너무 보고 싶어서 ㅇㅇㅇ.
# Redo Question:
#  11 약속을 안 -(지키다) 사람
# Answer: 약속을 안 지키는(지키다) 사람
# Redo Question:
#  13 리쿠 씨가 다른 약속이 있어서 못 -(가다)고 했어요.
# Answer: 리쿠 씨가 다른 약속이 있어서 못 간다(가다)고 했어요.
# Redo Question:
#  14 마크는 오늘 일하지 -(않다)고 했어요.
# Answer: 마크는 오늘 일하지 않는다(않다)고 했어요.
# Redo Question:
#  37 도독- 든 것 같아요.
# Answer: 도독이 든 것 같아요.
# Redo Question:
#  39 재민 씨가 밥을 먹을 때 의자에 -(앉다) 있어요.
# Answer: 재민 씨가 밥을 먹을 때 의자에 앉아(앉다) 있어요.
# Redo Question:
#  43 시계가 벽에 - 있어요.
# Answer: 시계가 벽에 결려 있어요.
# Redo Question:
#  44 책이 책상 위에 - 있어요.
# Answer: 책이 책상 위에 놓여 있어요.
# Redo Question:
#  45 책- 책상 위에 놓았어요.
# Answer: 책을 책상 위에 놓았어요.
# Redo Question:
#  57 웨이비는 산- 내려와서 점심을 먹었다.
# Answer: 웨이비는 산에서 내려와서 점심을 먹었다.
# Redo Question:
#  58 물가가 많이 -(오르다)서 먹고 싶은 것을 자 사지 못한다.
# Answer: 물가가 많이 올라(오르다)서 먹고 싶은 것을 자 사지 못한다.
# Redo Question:
#  62 유타:"제 머리가 너무 길어요?" 유타 씨는 자기 머리가 너무 -고 했다.
# Answer: 유타:"제 머리가 너무 길어요?" 유타 씨는 자기 머리가 너무 기냐고고 했다.
# Redo Question:
#  64 우리 할머니께서는 -(젊다)때 샌프란시스코에 사신 적이 있다고 하셨다.
# Answer: 우리 할머니께서는 젊으셨을(젊다)때 샌프란시스코에 사신 적이 있다고 하셨다.
# Redo Question:
#  71 추칙이 -(틀리다)다.
# Answer: 추칙이 틀리(틀리다)다.
# Redo Question:
#  78 커피를 -(마시다) 극장에 갔어요.
# Answer: 커피를 마시고(마시다) 극장에 갔어요.
# Redo Question:
#  81 살- 빼다
# Answer: 살을 빼다
# Redo Question:
#  89 의견- 반대하다/찬성하다.
# Answer: 의견에 반대하다/찬성하다.
# Redo Question:
#  91 축재- 준비되다.
# Answer: 축재를 준비되다.
# Redo Question:
#  94 저기 -(졸리다) 학생이 있다.
# Answer: 저기 졸리는(졸리다) 학생이 있다.
# Redo Question:
#  100 주사- 맞다
# Answer: 주사를 맞다
# Redo Question:
#  104 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 -요."
# Answer: 지성:"약속 시간을 못 지겨서 정말 죄송합니다". 마크: "천러야, 지성이가 약속 시간을 못 지겨서 정말 죄소하대요."
# Redo Question:
#  111 얼굴이 -(빨갛다)면
# Answer: 얼굴이 빨가(빨갛다)면
